# %% [markdown]
# <a href="https://colab.research.google.com/github/Layers5/Python-Notebook/blob/main/Python_Wk_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python Notes
# ##Week 1: Variables and Expressions
#
# ##Functions and vocab to know
# **Functions**
#
# ```
# print('') = having a function that gives an output of a word/sentence
# print() = to have an output be from a variable
# print('',end='') = keeps the output of a subsequent print statement on the same line
# int() = if a function is given as a string, then you use this function to turn it into and integer (to compute formulas with)
# input() = if you wish to gain input from the user (returns as a string)
# len() = is used to find the length of a string
# var[i] = is used to find the index of the i'th object in the string defined by the variable var; the first object as index [0] and the second has index [1]
# float() = creates floats; for integer, float, strings w/integers or fractions
# str() = creates strings; for any given input
# print(f{}'') = Allows you to compute any function while giving an output at the same time; you put the calculation/variable inside {} and leave any words like how you word normally format a print function
#
#
# ```
#
#
# **Vocab**
#
# -Program: a list of instructions for the computer to execute
#
# -Algortithm: an ordered list of instructions but expressed in pseudocode thus canot be executed by a computer
#
# -Pseudocode: expressed in huma language rather than programming language
#
# -Statement: also known as 'functions'
#
# -Variable: a name that holds a piece of information (value) of differing data types
#
#
#
#
#
# -Floating point: An integer in which it includes a decimal point
#
# -F-string: allows you to create a string with placeholder expressions that are evaluated as the program executes
#
# -Binary: stores values of base 2
# >0 0 0 0 0 0 0 0 : last value starting with 2^0 and the first value ending with 2^8
#
# -Whitespace: any space that lacks any text
#
# -Newline: another name for whitespace and is self-explanatory; is generated by the print() function
#
# -Math module: a module on python located in another file and specifically holds certain math expressions (pi, sin/cos/tan, sqrt, etc.);
# >Each time you reference this module or any module, you must put the name of the module  then the specific function you wish to use

# %%
import math
print(f'{math.sqrt(4)}')
# Out:
# 2.0

# %% [markdown]
# **Things to know**
#
# - there are 3 different language levels: *Machine level* (all made up of binary), *Assembly level* (made up of programming required for hardware like for the CPU), and the *High level*, which composes of the modern programming language
#
# -2 main times of translation types: "Compiling* (i.e. language implementation) or *Interpreted* (i.e. a sign language interpreter interpreting in real time for those who are deaf)
#
# -API's (Application Programming Interface) are the tools for programmers and are ;amguage libraries
#
# -Sequential (serial) Paradigms processing only one instruction is executed at a time
#
# -Parallel Paradigms executes multiple lines of code at once
#
#
# -If you wish to connect a string, you can use a plus sign to connect them
# >str1 = 'abc'
#
# >str2 = '123'
#
# >str3 = str1 + str2
#
# >print("Easy as", str3)
#
# >Output: Easy as abc123
#
# -**1+2** returns an *integer type*, **1+2.0** & **1.+2.0** both return as a *float type*
#
# >integer-to-float conversion returns 25 to 25.0 but float-to-integer conversion returns 4.9 to 4
#
# -There are some special f'strings that can return certain things depending on what you want:
# >print(f'{:s}') : returns as a string (normal)
#
# >print(f'{:d}') : returns as a decimal
#
# >print(f'{:b}') : returns as binary
#
# >print(f'{:.if}') : returns as a float with 'i' places after deciam
